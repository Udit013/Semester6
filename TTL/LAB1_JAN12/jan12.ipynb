# %%
# print("Hello Python!")
# counter1 =100
# counter2 =200
# miles=1000.0
# name ="John"
# print (counter1)
# print (miles)
# print (name)
# a,b,c=1,2,"john"
# print (a,b,c)
# print (type(counter2))
# print (type(miles))
# print (type(b))
# print (int(miles))
# print (type(int(miles)))

# #arthmetic operations
# print(counter1+counter2)
# print(counter1-counter2)
# print(counter1/counter2)
# print(counter1%counter2)
# print(counter1*counter2)

#lists
list1 = ["abc", 34, True, 34, "male"]
print (list1)
tinylist=[123, "john"]
print (list1[0])
print(list1[1:4])
print(tinylist *2)
list2=["shenron",13,list1,"yes",tinylist]
print(list2)
list3=["hi",1 ,list2,[7,"bye",2.0],9]
print(list3)

print(list1==list2)
length=len(list1)
print(length)
# minimum=min(list1)
# print(minimum)

list1.append(list3)
print(list1)
list1.count(34)
list1.index(34)
list3.insert(4,"hello")
list2.remove(13)
# list1.pop(obj=list1[-1])
list2.reverse()

#dictionary

employee1 = {
  "name" : "name1",
  "other details" : {
  "empid" : 556,
  "salary" : 50000
  }
}
employee2 = {
  "name" : "name2",
  "empid" : 100,
  "salary" : 40000
}
employee3 = {
  "name" : "name3",
  "empid" : 200,
  "salary" : 45000
}

department = {
  "emp 1" : employee1,
  "emp 2" : employee2,
  "emp 3" : employee3
}
print(employee1["other details"])
print(employee2["empid"])
print(department)
print(len(employee1))
list5=[employee3.keys()]
print(list5)
list6=[employee3.values()]
print(list6)


#tuples
tuple1=("apple","banana","cherry")
print(tuple1)
list7=list(tuple1)
list7.append(3)
tuple1=tuple(list7)
print(tuple1)
# Out:
# ['abc', 34, True, 34, 'male']
# abc
# [34, True, 34]
# [123, 'john', 123, 'john']
# ['shenron', 13, ['abc', 34, True, 34, 'male'], 'yes', [123, 'john']]
# ['hi', 1, ['shenron', 13, ['abc', 34, True, 34, 'male'], 'yes', [123, 'john']], [7, 'bye', 2.0], 9]
# False
# 5
# ['abc', 34, True, 34, 'male', ['hi', 1, ['shenron', 13, [...], 'yes', [123, 'john']], [7, 'bye', 2.0], 9]]
# {'empid': 556, 'salary': 50000}
# 100
# {'emp 1': {'name': 'name1', 'other details': {'empid': 556, 'salary': 50000}}, 'emp 2': {'name': 'name2', 'empid': 100, 'salary': 40000}, 'emp 3': {'name': 'name3', 'empid': 200, 'salary': 45000}}
# 2
# [dict_keys(['name', 'empid', 'salary'])]
# [dict_values(['name3', 200, 45000])]
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry', 3)
