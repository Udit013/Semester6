# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def one(state_name):
  df5 = df[df['STATE/UT'] == state_name]
  state_data = df5[df5['DISTRICT']=='TOTAL']
  sns.lineplot(x='Year', y='Rape', data=state_data)
  plt.title('RAPE cases per YEAR in {state_name}')
  plt.show()

def second(state_name):
  print("Enter the year:")
  x = int(input())
  print("Enter the crime:")
  crime = input()
  df5 = df[df['STATE/UT'] == state_name]
  state_data = df5[df5['Year'] == x]
  sns.barplot(x='DISTRICT', y=crime, data=state_data)
  plt.show()

def third(state_name):
  df5 = df[df['STATE/UT'] == state_name]
  state_data = df5.groupby("Year")[['Rape', 'Dowry Deaths', 'Kidnapping and Abduction', 'Assault on women with intent to outrage her modesty','Cruelty by Husband or his Relatives','Importation of Girls']].max().plot(kind='bar', figsize=(22, 7))
  plt.show()

def four( ):
  df.groupby(['Year']).sum().plot(kind='pie', y='Dowry Deaths')
  plt.show()

def five(state_name):
  print("Enter the crime:")
  crime = input()
  df5 = df[df['STATE/UT'] == state_name]
  sns.scatterplot(x='DISTRICT', y=crime, data=df5, hue='Year')
  plt.show()

data=pd.read_csv("/home/udit/Semester6/TTL/LAB4_FEB16/india-crime.csv")
df = data.drop_duplicates()

print('----------MAIN MENU-----------')
print('1. Rape Crime of a state per year.')
print('2. Division of a particular crime in all the districts of a state in a particular year.')
print('3. Division of all crimes in a particular state over the years.')
print('4. Division of particular crimes in all states over the years. ')
print('5. Division of a particular crime in all districts of a state over the years.' )

print('Enter your choice:')
choice=int(input())

if choice == 1:
  print('Enter State:(enter in capital)')
  state = input()
  one(state)

elif choice == 2:

  print('Enter State:(enter in capital)')
  state = input()
  second(state)

elif choice == 3:
  print('Enter State:(enter in capital)')
  state = input()
  third(state)

elif choice == 4:
  four()

elif choice == 5:
  print('Enter State:(enter in capital)')
  state = input()
  five(state)
# Out:
# ----------MAIN MENU-----------
# 1. Rape Crime of a state per year.
# 2. Division of a particular crime in all the districts of a state in a particular year.
# 3. Division of all crimes in a particular state over the years.
# 4. Division of particular crimes in all states over the years.
# 5. Division of a particular crime in all districts of a state over the years.
# Enter your choice:
# Enter State:(enter in capital)
# Enter the crime:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-372e9f175b5a> in <module>()
#      72   print('Enter State:(enter in capital)')
#      73   state = input()
# ---> 74   five(state)
#
# <ipython-input-10-372e9f175b5a> in five(state_name)
#      34   crime = input()
#      35   df5 = df[df['STATE/UT'] == state_name]
# ---> 36   sns.scatterplot(x='DISTRICT', y=crime, data=df5, hue='Year')
#      37   plt.show()
#      38
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     850
#     851         plot_data = self.establish_variables(
# --> 852             x, y, hue, size, style, units, data
#     853         )
#     854
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
# -> 7359     arrays = _homogenize(arrays, index, dtype)
#    7360
#    7361     # from BlockManager perspective
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _homogenize(data, index, dtype)
#    7667                 v = lib.fast_multiget(v, oindex.values, default=np.nan)
#    7668             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 7669                                 raise_cast_failure=False)
#    7670
#    7671         homogenized.append(v)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4147
#    4148             subarr = construct_1d_arraylike_from_scalar(
# -> 4149                 value, len(index), dtype)
#    4150
#    4151         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1199         if is_integer_dtype(dtype) and isna(value):
#    1200             dtype = np.float64
# -> 1201         subarr = np.empty(length, dtype=dtype)
#    1202         subarr.fill(value)
#    1203
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
